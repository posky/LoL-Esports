# %%
import math

import pandas as pd
import mwclient

from lol_fandom import SITE
from lol_fandom import get_leagues, get_tournaments
from lol_fandom import get_scoreboard_games, get_scoreboard_players
from lol_fandom import from_response

pd.set_option('display.max_columns', None)

# %%
class Team:
    q = math.log(10) / 400
    def __init__(self, name):
        self.name = name
        self.win = 0
        self.loss = 0
        self.r = 1000
        self.RD = 350

    def get_g(RDi):
        return 1 / math.sqrt(1 + (3 * Team.q ** 2 * RDi ** 2) / math.pi ** 2)

    def get_e(r0, ri, g):
        return 1 / (1 + 10 ** ((g * (r0 - ri)) / -400))

    def get_d(g, e):
        return 1 / (Team.q ** 2 * g ** 2 * e * (1 - e))
    
    def update_point(team1, team2, result):
        # team1 win - result = 1 team1 loss - result = 0
        assert isinstance(team1, Team)
        assert isinstance(team2, Team)

        team1_r = team1.r
        team2_r = team2.r
        team1_RD = team1.RD
        team2_RD = team2.RD

        team1._update_point(team2_r, team2_RD, result)
        team2._update_point(team1_r, team1_RD, 1 - result)

    def _update_point(self, ri, RDi, s):
        if s == 1:
            self.win += 1
        else:
            self.loss += 1

        g_RD = Team.get_g(RDi)
        e = Team.get_e(self.r, ri, g_RD)
        d_2 = Team.get_d(g_RD, e)
        self.r = self.r + Team.q / (1 / self.RD ** 2 + 1 / d_2) * g_RD * (s - e)

        self.RD = math.sqrt((1 / self.RD ** 2 + 1 / d_2) ** -1)

    def get_win_prob(self, opponent):
        return Team.get_e(self.r, opponent.r, Team.get_g(opponent.RD))

    def to_dict(self):
        data = {
            'Win': self.win,
            'Loss': self.loss,
            'WinRate': self.win / (self.win + self.loss) if self.win != 0 else 0,
            'r': self.r,
            'RD': self.RD
        }

        return data

# %%
leagues = get_leagues()
leagues
# Out:
#                                      League League Short         Region  \
# 0                       2015 All-Star Event     2015 ASE  International
# 1    2015 International Wildcard Tournament    2015 IWCT  International
# 2     2016 International Wildcard Qualifier         IWCQ  International
# 3                                  All-Star     All-Star  International
# 4                          Arena of Legends          AOL  North America
# ..                                      ...          ...            ...
# 120             Vietnam Championship Series          VCS        Vietnam
# 121                          Volcano League           VL  Latin America
# 122                      World Championship          WCS  International
# 123                       World Cyber Arena          WCA          China
# 124                           Xtreme League          XLG         Brazil
#
#          Level IsOfficial
# 0    Showmatch        Yes
# 1      Primary        Yes
# 2      Primary        Yes
# 3    Showmatch        Yes
# 4    Secondary         No
# ..         ...        ...
# 120    Primary        Yes
# 121  Secondary        Yes
# 122    Primary        Yes
# 123    Primary         No
# 124  Secondary         No
#
# [125 rows x 5 columns]

# %%
target_leagues = ['LCK', 'LPL', 'LEC', 'LCS']

# %%
tournaments = pd.DataFrame()
for league in target_leagues:
    t = get_tournaments(f'L.League_Short="{league}" and T.Year=2022')
    tournaments = pd.concat([tournaments, t])
tournaments = tournaments.reset_index(drop=True)
tournaments = tournaments.sort_values(by='DateStart')
tournaments
# Out:
#                         Name                     OverviewPage  DateStart  \
# 4            LPL 2022 Spring    LPL/2022 Season/Spring Season 2022-01-10
# 0            LCK 2022 Spring    LCK/2022 Season/Spring Season 2022-01-12
# 13          LCS 2022 Lock In          LCS/2022 Season/Lock In 2022-01-14
# 8            LEC 2022 Spring    LEC/2022 Season/Spring Season 2022-01-14
# 14           LCS 2022 Spring    LCS/2022 Season/Spring Season 2022-02-05
# 1   LCK 2022 Spring Playoffs  LCK/2022 Season/Spring Playoffs 2022-03-23
# 9   LEC 2022 Spring Playoffs  LEC/2022 Season/Spring Playoffs 2022-03-25
# 5   LPL 2022 Spring Playoffs  LPL/2022 Season/Spring Playoffs 2022-03-26
# 15  LCS 2022 Spring Playoffs  LCS/2022 Season/Spring Playoffs 2022-04-02
# 6            LPL 2022 Summer    LPL/2022 Season/Summer Season 2022-06-10
# 2            LCK 2022 Summer    LCK/2022 Season/Summer Season 2022-06-15
# 10           LEC 2022 Summer    LEC/2022 Season/Summer Season 2022-06-17
# 16           LCS 2022 Summer    LCS/2022 Season/Summer Season 2022-06-17
# 7   LPL 2022 Summer Playoffs  LPL/2022 Season/Summer Playoffs 2022-08-16
# 3   LCK 2022 Summer Playoffs  LCK/2022 Season/Summer Playoffs 2022-08-17
# 12     LCS 2022 Championship     LCS/2022 Season/Championship 2022-08-20
# 11  LEC 2022 Summer Playoffs  LEC/2022 Season/Summer Playoffs 2022-08-26
#
#          Date                                 League         Region  \
# 4  2022-03-25                 Tencent LoL Pro League          China
# 0  2022-03-20                    LoL Champions Korea          Korea
# 13 2022-01-30  League of Legends Championship Series  North America
# 8  2022-03-06              LoL European Championship         Europe
# 14 2022-03-27  League of Legends Championship Series  North America
# 1  2022-04-02                    LoL Champions Korea          Korea
# 9  2022-04-10              LoL European Championship         Europe
# 5  2022-04-23                 Tencent LoL Pro League          China
# 15 2022-04-24  League of Legends Championship Series  North America
# 6  2022-08-14                 Tencent LoL Pro League          China
# 2  2022-08-14                    LoL Champions Korea          Korea
# 10 2022-08-14              LoL European Championship         Europe
# 16 2022-08-14  League of Legends Championship Series  North America
# 7  2022-09-01                 Tencent LoL Pro League          China
# 3  2022-08-28                    LoL Champions Korea          Korea
# 12 2022-09-11  League of Legends Championship Series  North America
# 11 2022-09-11              LoL European Championship         Europe
#
#          EventType              StandardName   Split SplitNumber  \
# 4   Offline/Online           LPL 2022 Spring  Spring           1
# 0          Offline           LCK 2022 Spring  Spring           1
# 13            None          LCS 2022 Lock In  Spring           1
# 8           Online           LEC 2022 Spring  Spring           1
# 14            None           LCS 2022 Spring  Spring           1
# 1   Online/Offline  LCK 2022 Spring Playoffs  Spring           1
# 9             None  LEC 2022 Spring Playoffs  Spring           1
# 5           Online  LPL 2022 Spring Playoffs  Spring           1
# 15            None  LCS 2022 Spring Playoffs    None        None
# 6   Offline/Online           LPL 2022 Summer  Summer           2
# 2   Online/Offline           LCK 2022 Summer  Summer           2
# 10         Offline           LEC 2022 Summer  Summer           2
# 16            None           LCS 2022 Summer  Summer           2
# 7          Offline  LPL 2022 Summer Playoffs  Summer           2
# 3   Offline/Online  LCK 2022 Summer Playoffs  Summer           2
# 12  Online/Offline     LCS 2022 Championship  Summer           2
# 11  Online/Offline  LEC 2022 Summer Playoffs  Summer           2
#
#    TournamentLevel IsQualifier IsPlayoffs IsOfficial  Year  \
# 4          Primary           0          0          1  2022
# 0          Primary           0          0          1  2022
# 13         Primary           0          1          1  2022
# 8          Primary           0          0          1  2022
# 14         Primary           0          0          1  2022
# 1          Primary           0          1          1  2022
# 9          Primary           0          1          1  2022
# 5          Primary           0          1          1  2022
# 15         Primary           0          1          1  2022
# 6          Primary           0          0          1  2022
# 2          Primary           0          0          1  2022
# 10         Primary           0          0          1  2022
# 16         Primary           0          0          1  2022
# 7          Primary           0          1          1  2022
# 3          Primary           0          1          1  2022
# 12         Primary           0          1          1  2022
# 11         Primary           0          1          1  2022
#
#    DateStart__precision Date__precision
# 4                     1               1
# 0                     1               1
# 13                    1               1
# 8                     1               1
# 14                    1               1
# 1                     1               1
# 9                     1               1
# 5                     1               1
# 15                    1               1
# 6                     1               1
# 2                     1               1
# 10                    1               1
# 16                    1               1
# 7                     1               1
# 3                     1               1
# 12                    1               1
# 11                    1               1

# %%
teams = {}
for page in tournaments['OverviewPage']:
    scoreboard_games = get_scoreboard_games(f'T.OverviewPage="{page}"')
    scoreboard_games = scoreboard_games.sort_values(by='DateTime UTC', ascending=False).reset_index(drop=True)

    team_names = scoreboard_games[['Team1', 'Team2']].apply(pd.unique)
    team_names = list(set(list(team_names['Team1']) + list(team_names['Team2'])))
    for name in team_names:
        if name not in teams:
            teams[name] = Team(name)

    for row in scoreboard_games.itertuples():
        team1, team2 = row.Team1, row.Team2
        result= 1 if row.WinTeam == team1 else 0
        Team.update_point(teams[team1], teams[team2], result)

ratings = pd.DataFrame(
    data=map(lambda x: x.to_dict(), teams.values()),
    index=teams.keys()
)
ratings = ratings.sort_values(by='r', ascending=False)
ratings
# Out:
#                        Win  Loss   WinRate            r         RD
# Gen.G                   73    23  0.760417  1228.861781  42.562541
# G2 Esports              42    20  0.677419  1181.783919  51.708266
# T1                      76    26  0.745098  1178.892578  45.182113
# Rogue (European Team)   40    23  0.634921  1141.377280  49.509602
# JD Gaming               71    36  0.663551  1132.104004  38.304416
# Victory Five            65    30  0.684211  1124.625170  42.084190
# Top Esports             78    44  0.639344  1124.533616  34.030679
# Fnatic                  38    27  0.584615  1110.082072  48.901829
# Royal Never Give Up     64    36  0.640000  1109.527285  38.814881
# EDward Gaming           63    40  0.611650  1088.479728  37.130618
# DWG KIA                 61    40  0.603960  1085.534087  39.204640
# Evil Geniuses.NA        57    29  0.662791  1072.488284  45.431408
# MAD Lions               23    22  0.511111  1041.516044  59.433182
# Team Liquid             52    29  0.641975  1038.163590  47.005246
# Weibo Gaming            52    41  0.559140  1033.888794  39.330474
# 100 Thieves             42    28  0.600000  1032.759014  46.325380
# Misfits Gaming          25    26  0.490196  1027.755444  56.279469
# LNG Esports             55    49  0.528846  1025.220446  36.942331
# Cloud9                  44    28  0.611111  1022.350838  46.488779
# Excel Esports           23    24  0.489362  1005.938396  57.361294
# Bilibili Gaming         49    49  0.500000  1001.296580  39.132088
# Liiv SANDBOX            42    48  0.466667   999.179543  42.422840
# Team Vitality           21    24  0.466667   993.184233  58.985027
# KT Rolster              46    47  0.494624   990.426057  40.003846
# FunPlus Phoenix         45    50  0.473684   979.761776  38.411345
# Oh My God               43    46  0.483146   975.521339  40.570108
# DRX                     47    48  0.494737   967.922454  39.087272
# Rare Atom               35    49  0.416667   925.050090  42.078828
# Anyone's Legend         30    47  0.389610   916.075805  44.438797
# Invictus Gaming         31    51  0.378049   912.044943  43.774044
# SK Gaming               14    22  0.388889   909.304371  68.282698
# Counter Logic Gaming    27    31  0.465517   899.218124  52.624726
# Kwangdong Freecs        36    56  0.391304   895.574910  41.532650
# ThunderTalk Gaming      29    52  0.358025   895.100297  43.745765
# FlyQuest                26    32  0.448276   879.119898  52.947737
# Ultra Prime             27    52  0.341772   878.549057  44.054110
# Nongshim RedForce       30    57  0.344828   873.220526  43.743728
# LGD Gaming              28    56  0.333333   862.243039  44.292642
# Fredit BRION            32    57  0.359551   852.531254  41.431390
# Astralis                10    26  0.277778   849.255379  76.658330
# Hanwha Life Esports     24    65  0.269663   821.316930  44.205635
# Team WE                 21    58  0.265823   803.213402  45.793612
# TSM                     17    33  0.340000   795.047031  58.678408
# Golden Guardians        17    34  0.333333   780.060275  56.316345
# Dignitas                15    31  0.326087   767.666173  60.759735
# Team BDS                 7    29  0.194444   755.283573  76.294030
# Immortals                9    31  0.225000   693.187794  69.680642
