# %%
import math

import pandas as pd
import mwclient

from lol_fandom import SITE
from lol_fandom import get_leagues, get_tournaments
from lol_fandom import get_scoreboard_games, get_scoreboard_players
from lol_fandom import from_response

pd.set_option('display.max_columns', None)

# %%
class Team:
    q = math.log(10) / 400
    def __init__(self, name, league):
        self.name = name
        self.league = league
        self.win = 0
        self.loss = 0
        self.r = 1000
        self.RD = 350

    def get_g(RDi):
        return 1 / math.sqrt(1 + (3 * Team.q ** 2 * RDi ** 2) / math.pi ** 2)

    def get_e(r0, ri, g):
        return 1 / (1 + 10 ** ((g * (r0 - ri)) / -400))

    def get_d(g, e):
        return 1 / (Team.q ** 2 * g ** 2 * e * (1 - e))
    
    def update_point(team1, team2, result):
        # team1 win - result = 1 team1 loss - result = 0
        assert isinstance(team1, Team)
        assert isinstance(team2, Team)

        team1_r = team1.r
        team2_r = team2.r
        team1_RD = team1.RD
        team2_RD = team2.RD

        team1._update_point(team2_r, team2_RD, result)
        team2._update_point(team1_r, team1_RD, 1 - result)

    def _update_point(self, ri, RDi, s):
        if s == 1:
            self.win += 1
        else:
            self.loss += 1

        g_RD = Team.get_g(RDi)
        e = Team.get_e(self.r, ri, g_RD)
        d_2 = Team.get_d(g_RD, e)
        self.r = self.r + Team.q / (1 / self.RD ** 2 + 1 / d_2) * g_RD * (s - e)

        self.RD = math.sqrt((1 / self.RD ** 2 + 1 / d_2) ** -1)

    def get_win_prob(self, opponent):
        return Team.get_e(self.r, opponent.r, Team.get_g(opponent.RD))

    def to_dict(self):
        data = {
            'League': self.league,
            'Win': self.win,
            'Loss': self.loss,
            'WinRate': self.win / (self.win + self.loss) if self.win != 0 else 0,
            'r': self.r,
            'RD': self.RD
        }

        return data

# %%
def proceed_rating(teams, games):
    for row in games.itertuples():
        team1, team2 = row.Team1, row.Team2
        result = 1 if row.WinTeam == team1 else 0
        Team.update_point(teams[team1], teams[team2], result)

def get_rating(teams):
    ratings = pd.DataFrame(
        data=map(lambda x: x.to_dict(), teams.values()),
        index=teams.keys()
    )
    ratings = ratings.sort_values(by='r', ascending=False)
    return ratings

# %%
leagues = get_leagues()
leagues
# Out:
#                                      League League Short         Region  \
# 0                       2015 All-Star Event     2015 ASE  International
# 1    2015 International Wildcard Tournament    2015 IWCT  International
# 2     2016 International Wildcard Qualifier         IWCQ  International
# 3                                  All-Star     All-Star  International
# 4                          Arena of Legends          AOL  North America
# ..                                      ...          ...            ...
# 120             Vietnam Championship Series          VCS        Vietnam
# 121                          Volcano League           VL  Latin America
# 122                      World Championship          WCS  International
# 123                       World Cyber Arena          WCA          China
# 124                           Xtreme League          XLG         Brazil
#
#          Level IsOfficial
# 0    Showmatch        Yes
# 1      Primary        Yes
# 2      Primary        Yes
# 3    Showmatch        Yes
# 4    Secondary         No
# ..         ...        ...
# 120    Primary        Yes
# 121  Secondary        Yes
# 122    Primary        Yes
# 123    Primary         No
# 124  Secondary         No
#
# [125 rows x 5 columns]

# %%
target_leagues = ['LCK', 'LPL', 'LEC', 'LCS']

# %%
tournaments = pd.DataFrame()
for league in target_leagues:
    t = get_tournaments(f'L.League_Short="{league}" and T.Year=2022')
    tournaments = pd.concat([tournaments, t])
tournaments = tournaments.sort_values(by='DateStart').reset_index(drop=True)
tournaments
# Out:
#                         Name                     OverviewPage  DateStart  \
# 0            LPL 2022 Spring    LPL/2022 Season/Spring Season 2022-01-10
# 1            LCK 2022 Spring    LCK/2022 Season/Spring Season 2022-01-12
# 2           LCS 2022 Lock In          LCS/2022 Season/Lock In 2022-01-14
# 3            LEC 2022 Spring    LEC/2022 Season/Spring Season 2022-01-14
# 4            LCS 2022 Spring    LCS/2022 Season/Spring Season 2022-02-05
# 5   LCK 2022 Spring Playoffs  LCK/2022 Season/Spring Playoffs 2022-03-23
# 6   LEC 2022 Spring Playoffs  LEC/2022 Season/Spring Playoffs 2022-03-25
# 7   LPL 2022 Spring Playoffs  LPL/2022 Season/Spring Playoffs 2022-03-26
# 8   LCS 2022 Spring Playoffs  LCS/2022 Season/Spring Playoffs 2022-04-02
# 9            LPL 2022 Summer    LPL/2022 Season/Summer Season 2022-06-10
# 10           LCK 2022 Summer    LCK/2022 Season/Summer Season 2022-06-15
# 11           LEC 2022 Summer    LEC/2022 Season/Summer Season 2022-06-17
# 12           LCS 2022 Summer    LCS/2022 Season/Summer Season 2022-06-17
# 13  LPL 2022 Summer Playoffs  LPL/2022 Season/Summer Playoffs 2022-08-16
# 14  LCK 2022 Summer Playoffs  LCK/2022 Season/Summer Playoffs 2022-08-17
# 15     LCS 2022 Championship     LCS/2022 Season/Championship 2022-08-20
# 16  LEC 2022 Summer Playoffs  LEC/2022 Season/Summer Playoffs 2022-08-26
#
#          Date                                 League         Region  \
# 0  2022-03-25                 Tencent LoL Pro League          China
# 1  2022-03-20                    LoL Champions Korea          Korea
# 2  2022-01-30  League of Legends Championship Series  North America
# 3  2022-03-06              LoL European Championship         Europe
# 4  2022-03-27  League of Legends Championship Series  North America
# 5  2022-04-02                    LoL Champions Korea          Korea
# 6  2022-04-10              LoL European Championship         Europe
# 7  2022-04-23                 Tencent LoL Pro League          China
# 8  2022-04-24  League of Legends Championship Series  North America
# 9  2022-08-14                 Tencent LoL Pro League          China
# 10 2022-08-14                    LoL Champions Korea          Korea
# 11 2022-08-14              LoL European Championship         Europe
# 12 2022-08-14  League of Legends Championship Series  North America
# 13 2022-09-01                 Tencent LoL Pro League          China
# 14 2022-08-28                    LoL Champions Korea          Korea
# 15 2022-09-11  League of Legends Championship Series  North America
# 16 2022-09-11              LoL European Championship         Europe
#
#          EventType              StandardName   Split SplitNumber  \
# 0   Offline/Online           LPL 2022 Spring  Spring           1
# 1          Offline           LCK 2022 Spring  Spring           1
# 2             None          LCS 2022 Lock In  Spring           1
# 3           Online           LEC 2022 Spring  Spring           1
# 4             None           LCS 2022 Spring  Spring           1
# 5   Online/Offline  LCK 2022 Spring Playoffs  Spring           1
# 6             None  LEC 2022 Spring Playoffs  Spring           1
# 7           Online  LPL 2022 Spring Playoffs  Spring           1
# 8             None  LCS 2022 Spring Playoffs    None        None
# 9   Offline/Online           LPL 2022 Summer  Summer           2
# 10  Online/Offline           LCK 2022 Summer  Summer           2
# 11         Offline           LEC 2022 Summer  Summer           2
# 12            None           LCS 2022 Summer  Summer           2
# 13         Offline  LPL 2022 Summer Playoffs  Summer           2
# 14  Offline/Online  LCK 2022 Summer Playoffs  Summer           2
# 15  Online/Offline     LCS 2022 Championship  Summer           2
# 16  Online/Offline  LEC 2022 Summer Playoffs  Summer           2
#
#    TournamentLevel IsQualifier IsPlayoffs IsOfficial  Year  \
# 0          Primary           0          0          1  2022
# 1          Primary           0          0          1  2022
# 2          Primary           0          1          1  2022
# 3          Primary           0          0          1  2022
# 4          Primary           0          0          1  2022
# 5          Primary           0          1          1  2022
# 6          Primary           0          1          1  2022
# 7          Primary           0          1          1  2022
# 8          Primary           0          1          1  2022
# 9          Primary           0          0          1  2022
# 10         Primary           0          0          1  2022
# 11         Primary           0          0          1  2022
# 12         Primary           0          0          1  2022
# 13         Primary           0          1          1  2022
# 14         Primary           0          1          1  2022
# 15         Primary           0          1          1  2022
# 16         Primary           0          1          1  2022
#
#    DateStart__precision Date__precision
# 0                     1               1
# 1                     1               1
# 2                     1               1
# 3                     1               1
# 4                     1               1
# 5                     1               1
# 6                     1               1
# 7                     1               1
# 8                     1               1
# 9                     1               1
# 10                    1               1
# 11                    1               1
# 12                    1               1
# 13                    1               1
# 14                    1               1
# 15                    1               1
# 16                    1               1

# %%
teams = {}
for page in tournaments['OverviewPage']:
    scoreboard_games = get_scoreboard_games(f'T.OverviewPage="{page}"')
    scoreboard_games = scoreboard_games.sort_values(by='DateTime UTC').reset_index(drop=True)

    team_names = scoreboard_games[['Team1', 'Team2']].apply(pd.unique)
    team_names = list(set(list(team_names['Team1']) + list(team_names['Team2'])))
    league = page.split('/')[0]
    for name in team_names:
        if name not in teams:
            teams[name] = Team(name, league)

    proceed_rating(teams, scoreboard_games)

rating = get_rating(teams)
rating
# Out:
#                       League  Win  Loss   WinRate            r         RD
# Gen.G                    LCK   73    23  0.760417  1283.698751  42.535600
# T1                       LCK   76    26  0.745098  1232.852709  46.173128
# G2 Esports               LEC   42    20  0.677419  1210.338108  51.502710
# Evil Geniuses.NA         LCS   57    29  0.662791  1205.942719  44.627048
# Rogue (European Team)    LEC   40    23  0.634921  1174.650062  51.538549
# 100 Thieves              LCS   42    28  0.600000  1171.412948  47.155461
# Top Esports              LPL   78    44  0.639344  1170.792576  34.662074
# Team Liquid              LCS   52    29  0.641975  1169.181441  46.788766
# Victory Five             LPL   65    30  0.684211  1159.821938  41.237777
# JD Gaming                LPL   71    36  0.663551  1159.677366  37.458230
# Cloud9                   LCS   44    28  0.611111  1157.814337  46.909859
# Royal Never Give Up      LPL   64    36  0.640000  1138.556413  40.076397
# DWG KIA                  LCK   61    40  0.603960  1135.861677  39.707528
# Fnatic                   LEC   38    27  0.584615  1114.632511  48.703911
# EDward Gaming            LPL   63    40  0.611650  1099.257959  37.937241
# Weibo Gaming             LPL   52    41  0.559140  1053.759890  40.322593
# MAD Lions                LEC   23    22  0.511111  1050.949770  59.489605
# Misfits Gaming           LEC   25    26  0.490196  1044.699336  55.732477
# KT Rolster               LCK   46    47  0.494624  1044.337287  40.492738
# Liiv SANDBOX             LCK   42    48  0.466667  1044.240506  43.136842
# LNG Esports              LPL   55    49  0.528846  1040.185041  38.235120
# DRX                      LCK   47    48  0.494737  1031.050923  39.929701
# Excel Esports            LEC   23    24  0.489362  1012.487186  57.808935
# Counter Logic Gaming     LCS   27    31  0.465517  1012.391029  52.094872
# FlyQuest                 LCS   26    32  0.448276   992.201785  52.159293
# Bilibili Gaming          LPL   49    49  0.500000   986.075533  39.716464
# Oh My God                LPL   43    46  0.483146   985.569075  41.081775
# Team Vitality            LEC   21    24  0.466667   982.483599  60.130222
# FunPlus Phoenix          LPL   45    50  0.473684   971.178468  39.826965
# Kwangdong Freecs         LCK   36    56  0.391304   960.478812  41.962231
# TSM                      LCS   17    33  0.340000   938.268149  62.295926
# Anyone's Legend          LPL   30    47  0.389610   920.334650  45.062785
# Fredit BRION             LCK   32    57  0.359551   918.605106  41.569245
# SK Gaming                LEC   14    22  0.388889   916.235485  70.998050
# Nongshim RedForce        LCK   30    57  0.344828   909.808121  43.002088
# Rare Atom                LPL   35    49  0.416667   901.798593  41.735847
# Golden Guardians         LCS   17    34  0.333333   900.403043  56.963417
# Invictus Gaming          LPL   31    51  0.378049   896.437986  43.490012
# ThunderTalk Gaming       LPL   29    52  0.358025   881.162244  46.686172
# Dignitas                 LCS   15    31  0.326087   879.837302  60.301505
# Hanwha Life Esports      LCK   24    65  0.269663   855.969352  43.632079
# LGD Gaming               LPL   28    56  0.333333   849.094934  45.375749
# Ultra Prime              LPL   27    52  0.341772   846.123041  45.356729
# Astralis                 LEC   10    26  0.277778   845.369539  77.068959
# Immortals                LCS    9    31  0.225000   806.442404  70.296875
# Team WE                  LPL   21    58  0.265823   782.184812  47.129651
# Team BDS                 LEC    7    29  0.194444   718.136541  80.605147

# %%
tournaments = get_tournaments(f'L.League_Short="WCS" and T.Year=2022')
tournaments = tournaments.sort_values(by='DateStart').reset_index(drop=True)
tournaments
# Out:
#                                  Name  \
# 0            LCK 2022 Regional Finals
# 1  LPL 2022 Regional Finals Showmatch
# 2            LPL 2022 Regional Finals
# 3                 Worlds 2022 Play-In
# 4              Worlds 2022 Main Event
#
#                                 OverviewPage  DateStart       Date  \
# 0            LCK/2022 Season/Regional Finals 2022-09-01 2022-09-03
# 1  LPL/2022 Season/Regional Finals/Showmatch 2022-09-01 2022-09-01
# 2            LPL/2022 Season/Regional Finals 2022-09-02 2022-09-04
# 3     2022 Season World Championship/Play-In 2022-09-29 2022-10-04
# 4  2022 Season World Championship/Main Event 2022-10-07 2022-11-05
#
#                League         Region EventType  \
# 0  World Championship          Korea      None
# 1  World Championship          China   Offline
# 2  World Championship          China   Offline
# 3  World Championship  International   Offline
# 4  World Championship  International   Offline
#
#                          StandardName Split SplitNumber TournamentLevel  \
# 0            LCK 2022 Regional Finals  None        None         Primary
# 1  LPL 2022 Regional Finals Showmatch  None        None       Showmatch
# 2            LPL 2022 Regional Finals  None        None         Primary
# 3                 Worlds 2022 Play-In  None        None         Primary
# 4              Worlds 2022 Main Event  None        None         Primary
#
#   IsQualifier IsPlayoffs IsOfficial  Year DateStart__precision Date__precision
# 0           1          0          1  2022                    1               1
# 1           0          0          0  2022                    1               1
# 2           1          0          1  2022                    1               1
# 3           1          0          1  2022                    1               1
# 4           0          0          1  2022                    1               1

# %%
for page in tournaments['OverviewPage']:
    scoreboard_games = get_scoreboard_games(f'T.OverviewPage="{page}"')
    if scoreboard_games is None:
        continue
    scoreboard_games = scoreboard_games.sort_values(by='DateTime UTC').reset_index(drop=True)
    team_names = scoreboard_games[['Team1', 'Team2']].apply(pd.unique, axis=0, result_type='reduce')
    
    team_names = list(set(list(team_names['Team1']) + list(team_names['Team2'])))
    league = page.split('/')[0]
    for name in team_names:
        if name not in teams:
            teams[name] = Team(name, league)

    print(scoreboard_games.head())

    proceed_rating(teams, scoreboard_games)

rating = get_rating(teams)
rating
# Out:
#                       OverviewPage         Team1         Team2       WinTeam  \
# 0  LCK/2022 Season/Regional Finals       DWG KIA  Liiv SANDBOX       DWG KIA
# 1  LCK/2022 Season/Regional Finals  Liiv SANDBOX       DWG KIA  Liiv SANDBOX
# 2  LCK/2022 Season/Regional Finals       DWG KIA  Liiv SANDBOX       DWG KIA
# 3  LCK/2022 Season/Regional Finals  Liiv SANDBOX       DWG KIA       DWG KIA
# 4  LCK/2022 Season/Regional Finals    KT Rolster           DRX           DRX
#
#        LossTeam        DateTime UTC  Team1Score  Team2Score  Winner  \
# 0  Liiv SANDBOX 2022-09-01 08:08:00           1           0       1
# 1       DWG KIA 2022-09-01 09:04:00           1           1       1
# 2  Liiv SANDBOX 2022-09-01 10:01:00           2           1       1
# 3  Liiv SANDBOX 2022-09-01 10:52:00           1           3       2
# 4    KT Rolster 2022-09-02 08:05:00           0           1       2
#
#   Gamelength  Gamelength Number                                 Team1Bans  \
# 0      32:23          32.383333            Yuumi,Azir,Nautilus,Ornn,Poppy
# 1      33:09          33.150000  Renekton,Kalista,Sejuani,Swain,Lissandra
# 2      28:41          28.683333            Yuumi,Azir,Aphelios,Akali,Ahri
# 3      36:57          36.950000         Renekton,Sejuani,Draven,Gwen,None
# 4      41:25          41.416667            Poppy,Azir,Draven,Ornn,Trundle
#
#                                  Team2Bans  \
# 0     Renekton,Sivir,Kalista,Sylas,Taliyah
# 1              Azir,Yuumi,Sivir,Poppy,Ornn
# 2  Renekton,Kalista,Sejuani,Camille,Wukong
# 3              Yuumi,Azir,Kalista,Vi,Poppy
# 4         Renekton,Kalista,Ahri,Amumu,Lulu
#
#                                   Team1Picks  \
# 0           Aatrox,Sejuani,Swain,Lucian,Nami
# 1  Aatrox,Trundle,Ahri,Aphelios,Renata Glasc
# 2      Gwen,Lee Sin,Sylas,Sivir,Renata Glasc
# 3               Ornn,Trundle,Ahri,Sivir,Lulu
# 4      Aatrox,Sejuani,Taliyah,Sivir,Nautilus
#
#                          Team2Picks  \
# 0      Gragas,Vi,Ahri,Aphelios,Lulu
# 1           Yone,Vi,Vex,Lucian,Nami
# 2  Aatrox,Trundle,LeBlanc,Zeri,Lulu
# 3   Aatrox,Wukong,Sylas,Lucian,Nami
# 4     Fiora,Wukong,Sylas,Zeri,Yuumi
#
#                                         Team1Players  \
# 0             Nuguri,Canyon,ShowMaker,deokdam,Kellin
# 1  Dove,Croco,Clozer,Prince (Lee Chae-hwan),Kael ...
# 2             Nuguri,Canyon,ShowMaker,deokdam,Kellin
# 3  Dove,Croco,Clozer,Prince (Lee Chae-hwan),Kael ...
# 4                      Rascal,Cuzz,VicLa,Aiming,Life
#
#                                         Team2Players  Team1Dragons  \
# 0  Dove,Croco,Clozer,Prince (Lee Chae-hwan),Kael ...             4
# 1             Burdol,Canyon,ShowMaker,deokdam,Kellin             4
# 2  Dove,Croco,Clozer,Prince (Lee Chae-hwan),Kael ...             4
# 3             Nuguri,Canyon,ShowMaker,deokdam,Kellin             2
# 4       Kingen,Pyosik,Zeka (Kim Geon-woo),Deft,BeryL             3
#
#    Team2Dragons  Team1Barons  Team2Barons  Team1Towers  Team2Towers  \
# 0             0            0            1            7            2
# 1             1            1            0            8            5
# 2             0            1            0           10            0
# 3             3            0            1            3            7
# 4             2            1            2            7            9
#
#    Team1Gold  Team2Gold  Team1Kills  Team2Kills Team1RiftHeralds  \
# 0      58501      47928          13           1                2
# 1      62840      56103          18          11                1
# 2      53811      40435          14           1                2
# 3      54541      66254           5          13                2
# 4      73349      78782          11          18                2
#
#   Team2RiftHeralds  Team1Inhibitors  Team2Inhibitors  Patch  \
# 0                0                1                0  12.14
# 1                1                1                0  12.14
# 2                0                2                0  12.14
# 3                0                0                1  12.14
# 4                0                1                1  12.14
#
#                                         GameId  \
# 0  LCK/2022 Season/Regional Finals_Round 1_1_1
# 1  LCK/2022 Season/Regional Finals_Round 1_1_2
# 2  LCK/2022 Season/Regional Finals_Round 1_1_3
# 3  LCK/2022 Season/Regional Finals_Round 1_1_4
# 4  LCK/2022 Season/Regional Finals_Round 1_2_1
#
#                                      MatchId RiotGameId  \
# 0  LCK/2022 Season/Regional Finals_Round 1_1       None
# 1  LCK/2022 Season/Regional Finals_Round 1_1       None
# 2  LCK/2022 Season/Regional Finals_Round 1_1       None
# 3  LCK/2022 Season/Regional Finals_Round 1_1       None
# 4  LCK/2022 Season/Regional Finals_Round 1_2       None
#
#   DateTime UTC__precision
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
#                       OverviewPage                Team1                Team2  \
# 0  LPL/2022 Season/Regional Finals  Royal Never Give Up        EDward Gaming
# 1  LPL/2022 Season/Regional Finals        EDward Gaming  Royal Never Give Up
# 2  LPL/2022 Season/Regional Finals        EDward Gaming  Royal Never Give Up
# 3  LPL/2022 Season/Regional Finals  Royal Never Give Up        EDward Gaming
# 4  LPL/2022 Season/Regional Finals  Royal Never Give Up        EDward Gaming
#
#                WinTeam             LossTeam        DateTime UTC  Team1Score  \
# 0  Royal Never Give Up        EDward Gaming 2022-09-02 08:18:00           1
# 1  Royal Never Give Up        EDward Gaming 2022-09-02 09:22:00           0
# 2        EDward Gaming  Royal Never Give Up 2022-09-02 10:27:00           1
# 3        EDward Gaming  Royal Never Give Up 2022-09-02 11:21:00           2
# 4        EDward Gaming  Royal Never Give Up 2022-09-02 12:27:00           2
#
#    Team2Score  Winner Gamelength  Gamelength Number  \
# 0           0       1      35:58          35.966667
# 1           2       2      37:41          37.683333
# 2           2       1      27:36          27.600000
# 3           2       2      41:44          41.733333
# 4           3       2      31:44          31.733333
#
#                                Team1Bans                           Team2Bans  \
# 0    Kalista,Wukong,Lucian,Poppy,Sejuani    Fiora,Nautilus,Aatrox,Ahri,Sylas
# 1      Fiora,Vi,Poppy,Braum,Renata Glasc      Lucian,Yuumi,Azir,Amumu,Zilean
# 2  Poppy,Fiora,Lissandra,Aatrox,Renekton        Lucian,Yuumi,Ahri,Amumu,Ornn
# 3            Lucian,Wukong,Vi,Lulu,Fiora       Taliyah,Yuumi,Azir,Ahri,Akali
# 4           Lucian,Sejuani,Vi,Ahri,Akali  Yuumi,Taliyah,Fiora,Amumu,Nautilus
#
#                               Team1Picks                         Team2Picks  \
# 0             Jax,Vi,Taliyah,Sivir,Yuumi    Renekton,Trundle,Azir,Zeri,Lulu
# 1  Renekton,Sejuani,Sylas,Sivir,Nautilus    Aatrox,Wukong,Taliyah,Zeri,Lulu
# 2       Gragas,Vi,Taliyah,Sivir,Nautilus        Gnar,Sejuani,Azir,Zeri,Lulu
# 3    Aatrox,Poppy,Orianna,Sivir,Nautilus  Renekton,Sejuani,Sylas,Zeri,Braum
# 4        Aatrox,Trundle,Azir,Sivir,Leona       Gnar,Poppy,LeBlanc,Zeri,Lulu
#
#                                         Team1Players  \
# 0  Breathe,Wei (Yan Yang-Wei),Xiaohu,GALA,Ming (S...
# 1   Flandre,JunJia,Scout,Viper (Park Do-hyeon),Meiko
# 2   Flandre,Jiejie,Scout,Viper (Park Do-hyeon),Meiko
# 3  Breathe,Wei (Yan Yang-Wei),Xiaohu,GALA,Ming (S...
# 4  Breathe,Wei (Yan Yang-Wei),Xiaohu,GALA,Ming (S...
#
#                                         Team2Players  Team1Dragons  \
# 0   Flandre,JunJia,Scout,Viper (Park Do-hyeon),Meiko             3
# 1  Breathe,Wei (Yan Yang-Wei),Xiaohu,GALA,Ming (S...             2
# 2  Breathe,Wei (Yan Yang-Wei),Xiaohu,GALA,Ming (S...             2
# 3   Flandre,Jiejie,Scout,Viper (Park Do-hyeon),Meiko             1
# 4   Flandre,Jiejie,Scout,Viper (Park Do-hyeon),Meiko             1
#
#    Team2Dragons  Team1Barons  Team2Barons  Team1Towers  Team2Towers  \
# 0             3            1            0           10            2
# 1             3            0            1            7            9
# 2             1            1            0            9            4
# 3             4            2            1            9            7
# 4             3            0            1            2            7
#
#    Team1Gold  Team2Gold  Team1Kills  Team2Kills Team1RiftHeralds  \
# 0      67031      55777          18           5             None
# 1      64595      70912           6          22             None
# 2      51286      44975           9           4             None
# 3      69704      76646          10          20             None
# 4      47790      58206           0           9             None
#
#   Team2RiftHeralds  Team1Inhibitors  Team2Inhibitors  Patch  \
# 0             None                2                0  12.15
# 1             None                0                2  12.15
# 2             None                2                0  12.15
# 3             None                3                1  12.15
# 4             None                0                1  12.15
#
#                                         GameId  \
# 0  LPL/2022 Season/Regional Finals_Round 1_1_1
# 1  LPL/2022 Season/Regional Finals_Round 1_1_2
# 2  LPL/2022 Season/Regional Finals_Round 1_1_3
# 3  LPL/2022 Season/Regional Finals_Round 1_1_4
# 4  LPL/2022 Season/Regional Finals_Round 1_1_5
#
#                                      MatchId RiotGameId  \
# 0  LPL/2022 Season/Regional Finals_Round 1_1       None
# 1  LPL/2022 Season/Regional Finals_Round 1_1       None
# 2  LPL/2022 Season/Regional Finals_Round 1_1       None
# 3  LPL/2022 Season/Regional Finals_Round 1_1       None
# 4  LPL/2022 Season/Regional Finals_Round 1_1       None
#
#   DateTime UTC__precision
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
#                              OverviewPage                Team1  \
# 0  2022 Season World Championship/Play-In               Isurus
# 1  2022 Season World Championship/Play-In               Fnatic
# 2  2022 Season World Championship/Play-In                 LOUD
# 3  2022 Season World Championship/Play-In            MAD Lions
# 4  2022 Season World Championship/Play-In  Chiefs Esports Club
#
#                Team2        WinTeam             LossTeam        DateTime UTC  \
# 0          MAD Lions      MAD Lions               Isurus 2022-09-29 20:44:00
# 1   Evil Geniuses.NA         Fnatic     Evil Geniuses.NA 2022-09-29 22:35:00
# 2      Beyond Gaming  Beyond Gaming                 LOUD 2022-09-29 23:40:00
# 3  Istanbul Wildcats      MAD Lions    Istanbul Wildcats 2022-09-30 00:40:00
# 4             Fnatic         Fnatic  Chiefs Esports Club 2022-09-30 01:55:00
#
#    Team1Score  Team2Score  Winner Gamelength  Gamelength Number  \
# 0           0           1       2      37:59          37.983333
# 1           1           0       1      29:28          29.466667
# 2           0           1       2      28:44          28.733333
# 3           1           0       1      37:08          37.133333
# 4           0           1       2      29:53          29.883333
#
#                               Team1Bans                             Team2Bans  \
# 0      Draven,Aatrox,Sylas,Swain,Viktor  Caitlyn,Kalista,Sejuani,LeBlanc,Azir
# 1  Hecarim,Akali,Ornn,Jarvan IV,Lee Sin  Kalista,Yuumi,Sejuani,Karma,Nautilus
# 2    Sylas,Aatrox,Kalista,Akali,Taliyah        Caitlyn,Yuumi,Olaf,Galio,Leona
# 3   Kalista,Sejuani,Caitlyn,Amumu,Braum    Draven,Graves,Hecarim,Taliyah,Ahri
# 4  Sylas,Sejuani,Caitlyn,Nocturne,Poppy       Hecarim,Draven,Aatrox,Gnar,Ornn
#
#                                  Team1Picks  \
# 0  Ornn,Graves,Lissandra,Miss Fortune,Amumu
# 1   Aatrox,Graves,Viktor,Miss Fortune,Leona
# 2       Jax,Hecarim,Azir,Seraphine,Nautilus
# 3       Aatrox,Trundle,Sylas,Kai'Sa,Alistar
# 4          Gwen,Graves,Swain,Tristana,Braum
#
#                                    Team2Picks  \
# 0        Gnar,Hecarim,Taliyah,Seraphine,Leona
# 1            Renekton,Viego,Sylas,Caitlyn,Lux
# 2          Fiora,Sejuani,LeBlanc,Kai'Sa,Amumu
# 3  Renekton,Jarvan IV,Azir,Miss Fortune,Leona
# 4      Maokai,Lee Sin,Viktor,Kalista,Nautilus
#
#                                       Team1Players  \
# 0    ADD,Grell,seiya,Gavotto,Jelly (Son Ho-gyeong)
# 1              Wunder,Razork,Humanoid,Upset,Rhuckz
# 2                    Robo,Croc,tinowns,Brance,Ceos
# 3             Armut,Elyoya,Nisqy,UNF0RGIVEN,Kaiser
# 4  Topoon,Arthur (Park Mi-reu),Tally,Raes,Aladoric
#
#                                         Team2Players  Team1Dragons  \
# 0               Armut,Elyoya,Nisqy,UNF0RGIVEN,Kaiser             2
# 1  Impact,Inspired,jojopyun,Kaori,Vulcan (Philipp...             3
# 2                        Likai,Husha,Minji,Wako,Kino             0
# 3       StarScreen,Ferret,Serin,HolyPhoenix,Farfetch             2
# 4                Wunder,Razork,Humanoid,Upset,Rhuckz             1
#
#    Team2Dragons  Team1Barons  Team2Barons  Team1Towers  Team2Towers  \
# 0             2            0            3            5           10
# 1             1            1            0           10            2
# 2             4            0            1            3            9
# 3             3            1            1            9            4
# 4             2            0            1            3            9
#
#    Team1Gold  Team2Gold  Team1Kills  Team2Kills Team1RiftHeralds  \
# 0      63282      76009          12          22                0
# 1      59587      45801          10           2                2
# 2      44427      56850           3          21                2
# 3      70692      60724          20          11                2
# 4      48901      60855           6          17                2
#
#   Team2RiftHeralds  Team1Inhibitors  Team2Inhibitors  Patch  \
# 0                2                0                1  12.18
# 1                0                2                0  12.18
# 2                0                0                1  12.18
# 3                0                1                0  12.18
# 4                0                0                1  12.18
#
#                                              GameId  \
# 0  2022 Season World Championship/Play-In_Day 1_1_1
# 1  2022 Season World Championship/Play-In_Day 1_2_1
# 2  2022 Season World Championship/Play-In_Day 1_3_1
# 3  2022 Season World Championship/Play-In_Day 1_4_1
# 4  2022 Season World Championship/Play-In_Day 1_5_1
#
#                                           MatchId RiotGameId  \
# 0  2022 Season World Championship/Play-In_Day 1_1       None
# 1  2022 Season World Championship/Play-In_Day 1_2       None
# 2  2022 Season World Championship/Play-In_Day 1_3       None
# 3  2022 Season World Championship/Play-In_Day 1_4       None
# 4  2022 Season World Championship/Play-In_Day 1_5       None
#
#   DateTime UTC__precision
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
#                                                League  Win  Loss   WinRate  \
# Gen.G                                             LCK   73    23  0.760417
# T1                                                LCK   76    26  0.745098
# G2 Esports                                        LEC   42    20  0.677419
# Evil Geniuses.NA                                  LCS   62    31  0.666667
# Rogue (European Team)                             LEC   40    23  0.634921
# 100 Thieves                                       LCS   42    28  0.600000
# Top Esports                                       LPL   78    44  0.639344
# Team Liquid                                       LCS   52    29  0.641975
# JD Gaming                                         LPL   71    36  0.663551
# Cloud9                                            LCS   44    28  0.611111
# DetonatioN FocusMe     2022 Season World Championship    6     4  0.600000
# Victory Five                                      LPL   66    33  0.666667
# DWG KIA                                           LCK   64    41  0.609524
# Royal Never Give Up                               LPL   73    42  0.634783
# Fnatic                                            LEC   42    28  0.600000
# EDward Gaming                                     LPL   66    42  0.611111
# MAD Lions                                         LEC   29    25  0.537037
# DRX                                               LCK   58    52  0.527273
# Weibo Gaming                                      LPL   52    41  0.559140
# LNG Esports                                       LPL   60    53  0.530973
# Misfits Gaming                                    LEC   25    26  0.490196
# KT Rolster                                        LCK   48    50  0.489796
# Liiv SANDBOX                                      LCK   45    54  0.454545
# Excel Esports                                     LEC   23    24  0.489362
# Counter Logic Gaming                              LCS   27    31  0.465517
# FlyQuest                                          LCS   26    32  0.448276
# Bilibili Gaming                                   LPL   49    49  0.500000
# Oh My God                                         LPL   43    46  0.483146
# Team Vitality                                     LEC   21    24  0.466667
# LOUD                   2022 Season World Championship    4     6  0.400000
# FunPlus Phoenix                                   LPL   45    50  0.473684
# Kwangdong Freecs                                  LCK   36    56  0.391304
# TSM                                               LCS   17    33  0.340000
# Anyone's Legend                                   LPL   30    47  0.389610
# Fredit BRION                                      LCK   32    57  0.359551
# SK Gaming                                         LEC   14    22  0.388889
# Nongshim RedForce                                 LCK   30    57  0.344828
# Beyond Gaming          2022 Season World Championship    2     3  0.400000
# Rare Atom                                         LPL   35    49  0.416667
# Golden Guardians                                  LCS   17    34  0.333333
# Invictus Gaming                                   LPL   31    51  0.378049
# Saigon Buffalo         2022 Season World Championship    3     6  0.333333
# ThunderTalk Gaming                                LPL   29    52  0.358025
# Dignitas                                          LCS   15    31  0.326087
# Hanwha Life Esports                               LCK   24    65  0.269663
# LGD Gaming                                        LPL   28    56  0.333333
# Ultra Prime                                       LPL   27    52  0.341772
# Astralis                                          LEC   10    26  0.277778
# Immortals                                         LCS    9    31  0.225000
# Isurus                 2022 Season World Championship    1     4  0.200000
# Team WE                                           LPL   21    58  0.265823
# Team BDS                                          LEC    7    29  0.194444
# Istanbul Wildcats      2022 Season World Championship    0     5  0.000000
# Chiefs Esports Club    2022 Season World Championship    0     5  0.000000
#
#                                  r          RD
# Gen.G                  1283.698751   42.535600
# T1                     1232.852709   46.173128
# G2 Esports             1210.338108   51.502710
# Evil Geniuses.NA       1207.022399   43.160041
# Rogue (European Team)  1174.650062   51.538549
# 100 Thieves            1171.412948   47.155461
# Top Esports            1170.792576   34.662074
# Team Liquid            1169.181441   46.788766
# JD Gaming              1159.677366   37.458230
# Cloud9                 1157.814337   46.909859
# DetonatioN FocusMe     1154.272355  124.351186
# Victory Five           1144.766149   40.231072
# DWG KIA                1140.031656   38.789915
# Royal Never Give Up    1133.253700   37.071423
# Fnatic                 1123.814545   47.397145
# EDward Gaming          1105.455522   36.887084
# MAD Lions              1056.864507   54.631260
# DRX                    1056.117850   36.851193
# Weibo Gaming           1053.759890   40.322593
# LNG Esports            1053.625777   36.455608
# Misfits Gaming         1044.699336   55.732477
# KT Rolster             1039.134749   39.205099
# Liiv SANDBOX           1034.447850   40.533638
# Excel Esports          1012.487186   57.808935
# Counter Logic Gaming   1012.391029   52.094872
# FlyQuest                992.201785   52.159293
# Bilibili Gaming         986.075533   39.716464
# Oh My God               985.569075   41.081775
# Team Vitality           982.483599   60.130222
# LOUD                    980.184921  125.533429
# FunPlus Phoenix         971.178468   39.826965
# Kwangdong Freecs        960.478812   41.962231
# TSM                     938.268149   62.295926
# Anyone's Legend         920.334650   45.062785
# Fredit BRION            918.605106   41.569245
# SK Gaming               916.235485   70.998050
# Nongshim RedForce       909.808121   43.002088
# Beyond Gaming           907.762520  167.194547
# Rare Atom               901.798593   41.735847
# Golden Guardians        900.403043   56.963417
# Invictus Gaming         896.437986   43.490012
# Saigon Buffalo          881.809468  124.914663
# ThunderTalk Gaming      881.162244   46.686172
# Dignitas                879.837302   60.301505
# Hanwha Life Esports     855.969352   43.632079
# LGD Gaming              849.094934   45.375749
# Ultra Prime             846.123041   45.356729
# Astralis                845.369539   77.068959
# Immortals               806.442404   70.296875
# Isurus                  800.971708  172.797505
# Team WE                 782.184812   47.129651
# Team BDS                718.136541   80.605147
# Istanbul Wildcats       645.134806  174.058615
# Chiefs Esports Club     641.412656  186.515035

# %%
team_names = [
    'Gen.G', 'T1', 'DWG KIA', 'DRX', 
    'JD Gaming', 'Top Esports', 'EDward Gaming', 'Royal Never Give Up',
    'G2 Esports', 'Rogue (European Team)', 'Fnatic', 'MAD Lions',
    'Cloud9', '100 Thieves', 'Evil Geniuses.NA',
    'DetonatioN FocusMe', 'LOUD', 'Beyond Gaming', 'Saigon Buffalo', 'Isurus', 'Istanbul Wildcats', 'Chiefs Esports Club'
]

rating.loc[team_names]
# Out:
#                                                League  Win  Loss   WinRate  \
# Gen.G                                             LCK   73    23  0.760417
# T1                                                LCK   76    26  0.745098
# DWG KIA                                           LCK   64    41  0.609524
# DRX                                               LCK   58    52  0.527273
# JD Gaming                                         LPL   71    36  0.663551
# Top Esports                                       LPL   78    44  0.639344
# EDward Gaming                                     LPL   66    42  0.611111
# Royal Never Give Up                               LPL   73    42  0.634783
# G2 Esports                                        LEC   42    20  0.677419
# Rogue (European Team)                             LEC   40    23  0.634921
# Fnatic                                            LEC   42    28  0.600000
# MAD Lions                                         LEC   29    25  0.537037
# Cloud9                                            LCS   44    28  0.611111
# 100 Thieves                                       LCS   42    28  0.600000
# Evil Geniuses.NA                                  LCS   62    31  0.666667
# DetonatioN FocusMe     2022 Season World Championship    6     4  0.600000
# LOUD                   2022 Season World Championship    4     6  0.400000
# Beyond Gaming          2022 Season World Championship    2     3  0.400000
# Saigon Buffalo         2022 Season World Championship    3     6  0.333333
# Isurus                 2022 Season World Championship    1     4  0.200000
# Istanbul Wildcats      2022 Season World Championship    0     5  0.000000
# Chiefs Esports Club    2022 Season World Championship    0     5  0.000000
#
#                                  r          RD
# Gen.G                  1283.698751   42.535600
# T1                     1232.852709   46.173128
# DWG KIA                1140.031656   38.789915
# DRX                    1056.117850   36.851193
# JD Gaming              1159.677366   37.458230
# Top Esports            1170.792576   34.662074
# EDward Gaming          1105.455522   36.887084
# Royal Never Give Up    1133.253700   37.071423
# G2 Esports             1210.338108   51.502710
# Rogue (European Team)  1174.650062   51.538549
# Fnatic                 1123.814545   47.397145
# MAD Lions              1056.864507   54.631260
# Cloud9                 1157.814337   46.909859
# 100 Thieves            1171.412948   47.155461
# Evil Geniuses.NA       1207.022399   43.160041
# DetonatioN FocusMe     1154.272355  124.351186
# LOUD                    980.184921  125.533429
# Beyond Gaming           907.762520  167.194547
# Saigon Buffalo          881.809468  124.914663
# Isurus                  800.971708  172.797505
# Istanbul Wildcats       645.134806  174.058615
# Chiefs Esports Club     641.412656  186.515035
